# %%
from BrillharthMorrison import *

# %%
cff = CFF(9509)

# %%
cff.doAllStuff()
# Out:
# i = 0
#
# v_0 = 1, alpha_0 = 97.5141, a_0 = 97, u_0 = 97
# a = [97], b = [97], b^2 = [-100], B = [-1, 2, 5]
# [1 0 0] <-- -100
# Нету комбинаций, удовлетворяющих условия
# ####################################################################################################
# ####################################################################################################
#
# i = 1
#
# v_1 = 100, alpha_1 = 1.95, a_1 = 1, u_1 = 3
# a = [97, 1], b = [97, 98], b^2 = [-100, 95], B = [-1, 2, 5, 19]
# [1 0 0 0] <-- -100
# [0 0 1 1] <-- 95
# Нету комбинаций, удовлетворяющих условия
# ####################################################################################################
# ####################################################################################################
#
# i = 2
#
# v_2 = 95, alpha_2 = 1.05804, a_2 = 1, u_2 = 92
# a = [97, 1, 1], b = [97, 98, 195], b^2 = [-100, 95, -11], B = [-1, 2, 5, 11, 19]
# [1 0 0 0 0] <-- -100
# [0 0 1 0 1] <-- 95
# ...

# %%
# %%timeit
cff = CFF(17873)
cff.doAllStuff()
# Out:
# i = 0
#
# v_0 = 1, alpha_0 = 133.68994, a_0 = 133, u_0 = 133
# a = [133], b = [133], b^2 = [-184], B = [-1, 2, 23]
# [1 1 1] <-- -184
# Нету комбинаций, удовлетворяющих условия
# ####################################################################################################
# ####################################################################################################
#
# i = 1
#
# v_1 = 184, alpha_1 = 1.45, a_1 = 1, u_1 = 51
# a = [133, 1], b = [133, 134], b^2 = [-184, 83], B = [-1, 2, 23, 83]
# [1 1 1 0] <-- -184
# [0 0 0 1] <-- 83
# Нету комбинаций, удовлетворяющих условия
# ####################################################################################################
# ####################################################################################################
#
# i = 2
#
# v_2 = 83, alpha_2 = 2.22518, a_2 = 2, u_2 = 115
# a = [133, 1, 2], b = [133, 134, 401], b^2 = [-184, 83, -56], B = [-1, 2, 7, 23, 83]
# [1 1 0 1 0] <-- -184
# [0 0 0 0 1] <-- 83
# ...
